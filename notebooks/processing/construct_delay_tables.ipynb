# %%
import sys
MODULES_PATH = "../../modules"
if MODULES_PATH not in sys.path:
    sys.path.append(MODULES_PATH)
    
from hive_wrapper import HiveConnection
from utils import get_env_vars

# %%
username, _, _ = get_env_vars()
hive_connection = HiveConnection(*get_env_vars())

# %%
# all edges table creation
queries = [
    # drop mean tables
    f"""
    DROP TABLE IF EXISTS {username}.avg_delay_tsptype_tspsubtype_dper
    """,
    f"""
    DROP TABLE IF EXISTS {username}.avg_delay_tsptype_dper
    """,
    f"""
    DROP TABLE IF EXISTS {username}.avg_delay_dper
    """,
    f"""
    DROP TABLE IF EXISTS {username}.avg_delay
    """,
    
    # drop std tables
    f"""
    DROP TABLE IF EXISTS {username}.std_delay_tsptype_tspsubtype_dper
    """,
    f"""
    DROP TABLE IF EXISTS {username}.std_delay_tsptype_dper
    """,
    f"""
    DROP TABLE IF EXISTS {username}.std_delay_dper
    """,
    f"""
    DROP TABLE IF EXISTS {username}.std_delay
    """,
    
    # create mean tables
    f"""
    CREATE EXTERNAL TABLE {username}.avg_delay_tsptype_tspsubtype_dper(
        stop_name STRING,
        day_period STRING,
        transport_type STRING,
        transport_subtype STRING,
        mean_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/avg_delay_tsptype_tspsubtype_dper'
    """,
    f"""
    CREATE EXTERNAL TABLE {username}.avg_delay_tsptype_dper(
        stop_name STRING,
        day_period STRING,
        transport_type STRING,
        mean_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/avg_delay_tsptype_dper'
    """,
    f"""
    CREATE EXTERNAL TABLE {username}.avg_delay_dper(
        stop_name STRING,
        day_period STRING,
        mean_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/avg_delay_dper'
    """,
    f"""
    CREATE EXTERNAL TABLE {username}.avg_delay(
        stop_name STRING,
        mean_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/avg_delay'
    """,
    
    # create std tables
    f"""
    CREATE EXTERNAL TABLE {username}.std_delay_tsptype_tspsubtype_dper(
        stop_name STRING,
        day_period STRING,
        transport_type STRING,
        transport_subtype STRING,
        std_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/std_delay_tsptype_tspsubtype_dper'
    """,
    f"""
    CREATE EXTERNAL TABLE {username}.std_delay_tsptype_dper(
        stop_name STRING,
        day_period STRING,
        transport_type STRING,
        std_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/std_delay_tsptype_dper'
    """,
    f"""
    CREATE EXTERNAL TABLE {username}.std_delay_dper(
        stop_name STRING,
        day_period STRING,
        std_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/std_delay_dper'
    """,
    f"""
    CREATE EXTERNAL TABLE {username}.std_delay(
        stop_name STRING,
        std_arrival_delay DOUBLE
    )
    STORED AS PARQUET
    LOCATION '/user/{username}/delays/std_delay'
    """
]

for query in queries:
    hive_connection.exec(query)

# %%
hive_connection.pandas_df(f"select * from {username}.avg_delay_tsptype_tspsubtype_dper").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#   avg_delay_tsptype_tspsubtype_dper.stop_name  \
# 0                             uster, buchholz
# 1                         erlenbach zh, chapf
# 2                          herrliberg, rietli
# 3                           zürich, klusplatz
# 4                       zürich, loorenstrasse
#
#   avg_delay_tsptype_tspsubtype_dper.day_period  \
# 0                                      evening
# 1                                    afternoon
# 2                                    afternoon
# 3                                      morning
# 4                                      prenoon
#
#   avg_delay_tsptype_tspsubtype_dper.transport_type  \
# ...

# %%
hive_connection.pandas_df(f"select * from {username}.avg_delay_tsptype_dper").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#   avg_delay_tsptype_dper.stop_name avg_delay_tsptype_dper.day_period  \
# 0                 zürich, helmhaus                           morning
# 1              zürich, sihlquai/hb                           prenoon
# 2    zürich, museum für gestaltung                          latenoon
# 3      schlieren, spital limmattal                         afternoon
# 4        tagelswangen, buckstrasse                          latenoon
#
#   avg_delay_tsptype_dper.transport_type  \
# 0                                   bus
# 1                                   bus
# 2                                   bus
# 3                                   bus
# ...

# %%
hive_connection.pandas_df(f"select * from {username}.avg_delay_dper").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#   avg_delay_dper.stop_name avg_delay_dper.day_period  \
# 0   zürich, saalsporthalle                   morning
# 1           jonen, taverne                   prenoon
# 2           zufikon, emaus                 afternoon
# 3         wermatswil, post                   prenoon
# 4        bülach, sonnenhof                   prenoon
#
#    avg_delay_dper.mean_arrival_delay
# 0                          69.966324
# 1                          52.777302
# 2                          91.261469
# 3                          66.038642
# 4                          75.602920

# %%
hive_connection.pandas_df(f"select * from {username}.avg_delay").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#               avg_delay.stop_name  avg_delay.mean_arrival_delay
# 0                 illnau, wingert                     99.747988
# 1  zürich, birch-/glatttalstrasse                     86.426347
# 2                       stettbach                     48.685057
# 3                zürich, hubertus                     82.628606
# 4   wettswil a.a., strumbergächer                     79.446181

# %%
hive_connection.pandas_df(f"select * from {username}.std_delay_tsptype_tspsubtype_dper").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#   std_delay_tsptype_tspsubtype_dper.stop_name  \
# 0                     bachenbülach, alte post
# 1                          bonstetten, lätten
# 2                          bonstetten, lätten
# 3                        bremgarten ag, waage
# 4                             buchs zh, linde
#
#   std_delay_tsptype_tspsubtype_dper.day_period  \
# 0                                    afternoon
# 1                                     latenoon
# 2                                      morning
# 3                                      evening
# 4                                      morning
#
#   std_delay_tsptype_tspsubtype_dper.transport_type  \
# ...

# %%
hive_connection.pandas_df(f"select * from {username}.std_delay_tsptype_dper").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#   std_delay_tsptype_dper.stop_name std_delay_tsptype_dper.day_period  \
# 0          dübendorf, bahnhof nord                          latenoon
# 1             effretikon, moosburg                          latenoon
# 2             glattbrugg, glatthof                          latenoon
# 3          hausen am albis, heisch                          latenoon
# 4                   kloten, bramen                          latenoon
#
#   std_delay_tsptype_dper.transport_type  \
# 0                                   bus
# 1                                   bus
# 2                                   bus
# 3                                   bus
# ...

# %%
hive_connection.pandas_df(f"select * from {username}.std_delay_dper").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#         std_delay_dper.stop_name std_delay_dper.day_period  \
# 0              bülach, sonnenhof                   prenoon
# 1  dietlikon, dübendorferstrasse                   evening
# 2               dänikon, rotflue                 afternoon
# 3        embrach, zürcherstrasse                   prenoon
# 4        hausen am albis, heisch                  latenoon
#
#    std_delay_dper.std_arrival_delay
# 0                        167.157518
# 1                        103.978102
# 2                         63.677585
# 3                         55.772944
# 4                        235.475127

# %%
hive_connection.pandas_df(f"select * from {username}.std_delay").head()
# Out:
# /home/jovyan/work/final-project/notebooks/../modules/hive_wrapper.py:100: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   self.cache[query] = pd.read_sql(query, self.conn)
#               std_delay.stop_name  std_delay.std_arrival_delay
# 0            geroldswil, grindlen                   220.717430
# 1                 illnau, wingert                   266.002269
# 2                       stettbach                    73.486604
# 3  zürich, birch-/glatttalstrasse                   121.840268
# 4                zürich, hubertus                   162.825505

# %%
hive_connection.close()
